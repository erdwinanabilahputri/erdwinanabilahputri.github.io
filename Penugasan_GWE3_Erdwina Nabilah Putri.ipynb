# %% [markdown]
# # Penugasan Study Group GWE (Grow With EDM) - Modul 3: Exploratory Data Analysis (EDA)
#
# ## Instruksi Pengerjaan
# 1. Kerjakan notebook ini dengan mengisi bagian block code yang kosong dan menjawab bagian **Analisis Output**. Sesuai aturan: **1 block code hanya untuk 1 output**.
# 2. **Aturan Utama:** Kamu **DIPERBOLEHKAN** menggunakan AI (seperti ChatGPT, Claude, Gemini, dll) untuk membantu menulis kode Python. Namun, **HARAM HUKUMNYA** menggunakan AI untuk menulis bagian analisis (markdown). Analisis harus diketik sendiri berdasarkan pemahaman dan logikamu dari output kode yang dihasilkan. *Ingat: Tidak ada yang benar atau salah mutlak dalam analisis data, yang penting logikanya masuk!*
# 3. Setelah selesai, *upload* file notebook ini (`.ipynb`) ke repositori GitHub masing-masing sebagai portofolio.
# 4. Kumpulkan (submit) link repositori GitHub kamu melalui Google Form berikut: https://forms.gle/Tx1yu81jzTWfNGCL6
#
# ## Petunjuk & Tujuan Penugasan
# - **Tujuan:** Melatih kemampuan analisis hasil visualisasi/data dan pembuatan hipotesis atau kesimpulan bisnis berdasarkan tahapan materi EDA Modul 3.
# - **Dataset:** `ecommerce_sales_data.csv` (berisi data transaksi penjualan produk e-commerce).
# - **Langkah-langkah:** Ikuti soal-soal di bawah ini secara berurutan. Baca deskripsi soal, perhatikan *hint*, tulis kodenya, jalankan, dan berikan analisismu.

# %% [markdown]
# ## BAB I & II: Introduction to Pandas & Initial Data Understanding

# %% [markdown]
# ### Soal 1: Import Library & Load Dataset
# **Deskripsi:** Import library pandas, matplotlib.pyplot, dan seaborn. Lalu load dataset `ecommerce_sales_data.csv` dan tampilkan 5 baris pertamanya.
# **Hint:** Gunakan `pd.read_csv()` dan `.head()`.

# %%
# Tulis kode untuk Soal 1 di sini
import pandas as pd
import matplotlib.pyplot  as plt
import  seaborn as sns

df = pd.read_csv('ecommerce_sales_data.csv')
df.head()
# Out:
#    Order Date Product Name     Category Region  Quantity  Sales  Profit
# 0  2024-12-31      Printer       Office  North         4   3640  348.93
# 1  2022-11-27        Mouse  Accessories   East         7   1197  106.53
# 2  2022-05-11       Tablet  Electronics  South         5   5865  502.73
# 3  2024-03-16        Mouse  Accessories  South         2    786  202.87
# 4  2022-09-10        Mouse  Accessories   West         1    509  103.28

# %% [markdown]
# **Tuliskan Analisis Output Soal 1:**
# - *Tulis analisismu di sini...*
# disini menampilkan hasil dari dataset csv e-commerse yang dimana ada order date, product name,category,region.quantity,sales dan profit

# %% [markdown]
# ### Soal 2: Melihat Dimensi Data
# **Deskripsi:** Cek berapa banyak jumlah baris dan kolom dari dataset.
# **Hint:** Gunakan `.shape`.

# %%
# Tulis kode untuk Soal 2 di sini
df.shape
# Out:
# (3500, 7)

# %% [markdown]
# **Tuliskan Analisis Output Soal 2:**
# - *Tulis analisismu di sini...
#
# disini hasilya muncul angka yang menghasilkan berapa baris yg ada di data tersebut
#
#
# *

# %% [markdown]
# ### Soal 3: Validasi Tipe Data
# **Deskripsi:** Tampilkan informasi mengenai struktur kolom dan tipe data masing-masing kolom.
# **Hint:** Gunakan `.info()`.

# %%
# Tulis kode untuk Soal 3 di sini
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order Date    3500 non-null   str
#  1   Product Name  3500 non-null   str
#  2   Category      3500 non-null   str
#  3   Region        3500 non-null   str
#  4   Quantity      3500 non-null   int64
#  5   Sales         3500 non-null   int64
#  6   Profit        3500 non-null   float64
# dtypes: float64(1), int64(2), str(4)
# memory usage: 191.5 KB

# %% [markdown]
# **Tuliskan Analisis Output Soal 3:**
# - *Tulis analisismu di sini...
# info menampilkn kolom denga tipe data juga non null count
#
# *

# %% [markdown]
# ### Soal 4: Statistik Deskriptif
# **Deskripsi:** Tampilkan ringkasan statistik (mean, min, max, kuartil) untuk seluruh kolom numerik.
# **Hint:** Gunakan `.describe()`.

# %%
# Tulis kode untuk Soal 4 di sini
df.describe()
# Out:
#           Quantity         Sales       Profit
# count  3500.000000   3500.000000  3500.000000
# mean      4.931714   3047.966000   527.047203
# std       2.575895   2440.213237   504.139732
# min       1.000000     51.000000     6.970000
# 25%       3.000000   1049.500000   158.695000
# 50%       5.000000   2350.500000   361.070000
# 75%       7.000000   4537.000000   729.125000
# max       9.000000  10782.000000  2946.930000

# %% [markdown]
# **Tuliskan Analisis Output Soal 4:**
# - *Tulis analisismu di sini...
#
# disini describe menhasilkan data dari nilai mean,min,max dan kuartil dari kolom menarik
# *

# %% [markdown]
# ## BAB III: Data Cleaning for EDA

# %% [markdown]
# ### Soal 5: Merapikan Nama Kolom
# **Deskripsi:** Nama kolom yang menggunakan spasi kadang menyulitkan pemanggilan. Ubah nama kolom `Order Date` menjadi `Order_Date` dan `Product Name` menjadi `Product_Name`.
# **Hint:** Gunakan `df = df.rename(columns={...})` lalu panggil `df.columns` untuk memastikan.

# %%
# Tulis kode untuk Soal 5 di sini
df = df.rename(columns=
{
'Order Date' :'Order_Date',
'Product Name' : 'Product_Name'
})

print(df.columns)
# Out:
# Index(['Order_Date', 'Product_Name', 'Category', 'Region', 'Quantity', 'Sales',
#        'Profit'],
#       dtype='str')

# %% [markdown]
# **Tuliskan Analisis Output Soal 5:**
# - *Tulis analisismu di sini...
#
# disini untuk memudahan pemanggilan ada kolom kategori yang tidak menggunakan underscore(_)dan yaitu data kategory yang memakai spasi diubah ke category yang ada tanda (_)
# *

# %% [markdown]
# ### Soal 6: Cek Missing Values
# **Deskripsi:** Periksa apakah terdapat data kosong (null/NaN) pada setiap kolom.
# **Hint:** Gunakan `.isnull().sum()` atau `.isna().sum()`.

# %%
# Tulis kode untuk Soal 6 di sini
df.isnull().sum()
# Out:
# Order_Date      0
# Product_Name    0
# Category        0
# Region          0
# Quantity        0
# Sales           0
# Profit          0
# dtype: int64

# %% [markdown]
# **Tuliskan Analisis Output Soal 6:**
# - *Tulis analisismu di sini...
#
# semua kolom dai dataset null*

# %% [markdown]
# ### Soal 7: Cek Data Ganda (Duplicates)
# **Deskripsi:** Hitung jumlah baris data yang terduplikasi secara identik.
# **Hint:** Gunakan `.duplicated().sum()`.

# %%
# Tulis kode untuk Soal 7 di sini
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Tuliskan Analisis Output Soal 7:**
# - *Tulis analisismu di sini...
# untuk mengecek data yang terduplikasi kita memakai .duplicated dan mencari jumlahnya yaitu dengan sum()
#
# *

# %% [markdown]
# ## BAB IV: Univariate Analysis (Visualizing Distributions)

# %% [markdown]
# ### Soal 8: Distribusi Data Kategori
# **Deskripsi:** Buat visualisasi Bar Chart untuk melihat sebaran frekuensi jumlah transaksi pada setiap `Category`.
# **Hint:** Gunakan `df['Category'].value_counts().plot(kind='bar')` atau `sns.countplot()`.

# %%
# Tulis kode untuk Soal 8 di sini
df['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# **Tuliskan Analisis Output Soal 8:**
# - *Tulis analisismu di sini...*

# %% [markdown]
# ### Soal 9: Distribusi Data Numerik
# **Deskripsi:** Buat histogram untuk melihat distribusi data pada kolom `Sales`.
# **Hint:** Gunakan `sns.histplot(df['Sales'], kde=True)`.

# %%
# Tulis kode untuk Soal 9 di sini
sns.histplot(df['Sales'], kde=True)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %% [markdown]
# **Tuliskan Analisis Output Soal 9:**
# - *Tulis analisismu di sini...*

# %% [markdown]
# ### Soal 10: Deteksi Pencilan (Outliers)
# **Deskripsi:** Gunakan Boxplot untuk mendeteksi apakah ada pencilan (outlier) pada data `Profit`.
# **Hint:** Gunakan `sns.boxplot(y=df['Profit'])`.

# %%
# Tulis kode untuk Soal 10 di sini
sns.boxplot(y=df['Profit'])
# Out:
# <Axes: ylabel='Profit'>

# %% [markdown]
# **Tuliskan Analisis Output Soal 10:**
# - *Tulis analisismu di sini...*

# %% [markdown]
# ## BAB V: Multivariate Analysis & Correlation

# %% [markdown]
# ### Soal 11: Bivariate - Kategori vs Numerik
# **Deskripsi:** Bisnis ingin tahu kategori produk mana yang paling menguntungkan. Buat visualisasi Bar Chart yang menampilkan total Profit untuk setiap `Category`.
# **Hint:** Lakukan `.groupby('Category')['Profit'].sum().reset_index()` terlebih dahulu, lalu hasilnya di-plot dengan barplot.

# %%
# Tulis kode untuk Soal 11 di sini
df.groupby('Category')['Profit'].sum().reset_index()
# Out:
#       Category     Profit
# 0  Accessories  736084.74
# 1  Electronics  923185.59
# 2       Office  185394.88

# %% [markdown]
# **Tuliskan Analisis Output Soal 11:**
# - *Tulis analisismu di sini...*

# %% [markdown]
# ### Soal 12: Bivariate - Numerik vs Numerik (Scatter Plot)
# **Deskripsi:** Buat Scatter Plot untuk melihat hubungan antara `Sales` dan `Profit`.
# **Hint:** Gunakan `sns.scatterplot()`.

# %%
# Tulis kode untuk Soal 12 di sini
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=df, x='Sales', y='Profit')

plt.title('Hubungan antara Sales dan Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# **Tuliskan Analisis Output Soal 12:**
# - *Tulis analisismu di sini...*

# %% [markdown]
# ### Soal 13: Pair Plot (Pemetaan Masif)
# **Deskripsi:** Buat Pair Plot untuk melihat hubungan antar semua variabel numerik secara serentak.
# **Hint:** Gunakan `sns.pairplot(df[['Quantity', 'Sales', 'Profit']])`.

# %%
# Tulis kode untuk Soal 13 di sini
sns.pairplot(df[['Quantity', 'Sales', 'Profit']])

# %% [markdown]
# **Tuliskan Analisis Output Soal 13:**
# - *Tulis analisismu di sini...*

# %% [markdown]
# ### Soal 14: Korelasi & Heatmap
# **Deskripsi:** Tampilkan matriks korelasi dalam bentuk Heatmap beserta angka kekuatannya.
# **Hint:** Gunakan `sns.heatmap(df.corr(numeric_only=True), annot=True)`.

# %%
# Tulis kode untuk Soal 14 di sini
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **Tuliskan Analisis Output Soal 14:**
# - *Tulis analisismu di sini...*

# %% [markdown]
# ## BAB VI: Insights & Hypothesis Generation
# Berdasarkan seluruh hasil Exploratory Data Analysis (EDA) yang telah kamu lakukan di atas, tuliskan minimal 3 poin kesimpulan atau hipotesis bisnis yang bisa kamu berikan kepada tim manajemen!

# %% [markdown]
# **Jawaban:**
# 1. dari tugas yang pertama kita bisa membantu proses bisnis agar data lebih rapi dan dipanggil untuk kolom kategori
# 2. dari untuk visual membantu tim manajemen memahami statistik data apakah menurun atau meningkat disesuaikan dengan tahunnya serta bisa memprediksi kondisi
# 3. dan pada kolom mengecek data duplikat dan data yang kosong membantu tim manajemen mengolah dataset yang nantinya mudah diolah
